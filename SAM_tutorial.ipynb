# %% [markdown]
# # Segment Anything Model tutorial

# %%
# Setup the project and install dependencies
# !uv init
# !uv add numpy torch matplotlib opencv-python pandas zenodo-get
#!uv pip install git+https://github.com/facebookresearch/segment-anything.git

# %%
# Install dependencies on Google Colab
# !uv sync

# %%
# Download the SAM model weights
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth

# %%
# Download the dataset. You can skip this step if you already have a dataset in mind.
# !zenodo_get -doi 10.5281/zenodo.7938231 -o data/
# Out:
# Title: Potato Leaf data set
# Keywords:
# Publication date: 2023-05-16
# DOI: 10.5281/zenodo.7938231
# Total size: 1.3 GB
#
# ...
# File: IMG_8039.JPG (3.5 MB)
# Link: https://zenodo.org/api/records/7938231/files/IMG_8039.JPG/content
# 100% [......................................................] 3543471 / 3543471
# Checksum is correct for IMG_8039.JPG. (2102620bb925bf12d986274386d3ca5d)
#
# ...
# File: IMG_8040.JPG (3.8 MB)
# Link: https://zenodo.org/api/records/7938231/files/IMG_8040.JPG/content
# 100% [......................................................] 3767445 / 3767445
# Checksum is correct for IMG_8040.JPG. (650128cef8569a4708496828b851dd7d)
#
# ...
# File: IMG_8037.JPG (3.6 MB)
# Link: https://zenodo.org/api/records/7938231/files/IMG_8037.JPG/content
# 100% [......................................................] 3632114 / 3632114
# Checksum is correct for IMG_8037.JPG. (6136bb81214b3d1a71463a69985d8216)
#
# ...
# File: IMG_8035.JPG (3.9 MB)
# ...

# %% [markdown]
# Install dependencies

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import cv2
import torch

# %%
data_dir = "data/"
img_names = [i for i in os.listdir(data_dir) if i.endswith('.JPG')]
